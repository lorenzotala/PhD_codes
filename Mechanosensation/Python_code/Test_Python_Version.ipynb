# %%
import numpy as np
import bokeh.plotting
import bokeh.io

bokeh.io.output_notebook()

# Generate plotting values
t = np.linspace(0, 2*np.pi, 200)
x = 13 * np.cos(t) - 5 * np.cos(2*t) - 2 * np.cos(3*t) - np.cos(4*t)
y = 16 * np.sin(-t)**3
#13 * np.cos(t) - 5 * np.cos(2*t) - 2 * np.cos(3*t) - np.cos(4*t) 16 * np.sin(t)**3

p = bokeh.plotting.figure(height=250, width=275)
p.line(x, y, color='red', line_width=3)
text = bokeh.models.Label(x=0, y=0, text='bootcamp', text_align='center')
p.add_layout(text)

bokeh.io.show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4035">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="13d7c6b4-1e40-4e72-bbaf-a01ff287b217" data-root-id="4036"></div>

# %%
# %load_ext watermark
# %watermark -v -p numpy,bokeh,jupyterlab
# Out:
# Python implementation: CPython
# Python version       : 3.8.5
# IPython version      : 7.19.0
#
# numpy     : 1.19.2
# bokeh     : 2.2.3
# jupyterlab: 2.2.6
