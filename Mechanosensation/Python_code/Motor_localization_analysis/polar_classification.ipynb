# %%
import functools
import pandas as pd
import numpy as np
import tensorflow as tf

# %%
TRAIN_DATA_URL='D:/BacStalk/Download_code/Profiles_PilB_liq_BR1.csv'
LABEL_PATH='D:/BacStalk/Download_code/Profiles_PilB_liq_BR1_labels.csv'
df = pd.read_csv('D:/BacStalk/Download_code/Profiles_PilB_liq_BR1.csv', sep=',', na_values='*')
#train_file_path = tf.keras.utils.get_file("Profiles_PilB_liq_BR1.csv", TRAIN_DATA_URL)
df.head()
# Out:
#    0.002822  0.0034646  0.0041072  0.0047498  0.0053924  0.0060349  0.0063439  \
# 0  0.003906   0.003757   0.003608   0.003459   0.003309   0.003160   0.003124
# 1  0.002747   0.003041   0.003334   0.003628   0.003922   0.004216   0.004198
# 2  0.004849   0.005391   0.005933   0.006474   0.007016   0.007557   0.007975
# 3  0.000000   0.000037   0.000074   0.000111   0.000148   0.000185   0.000223
# 4  0.007186   0.007105   0.007023   0.006941   0.006860   0.006778   0.006696
#
#    0.0059249  0.005506  0.005087  ...  0.012759  0.012129  0.011499  0.010869  \
# 0   0.003123  0.003123  0.003122  ...  0.019048  0.019226  0.019403  0.019581
# 1   0.004083  0.003969  0.003854  ...  0.007032  0.006939  0.006847  0.006755
# 2   0.007670  0.007366  0.007062  ...  0.007425  0.006840  0.006255  0.005670
# 3   0.000744  0.001280  0.001816  ...  0.004031  0.004421  0.004811  0.005194
# 4   0.006440  0.006135  0.005830  ...  0.008690  0.008168  0.007646  0.007211
#
# ...
